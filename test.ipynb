# %%
import pandas as pd

# %%
df = pd.read_csv("absence.csv", delimiter = ";")
df = df[(df["Indicator"] == "Absence for Maternity or Adoption Leave") | (df["Indicator"] == "Absence for Paternity and Childcare Leave")]
df = df[df["Type de contrat"] == "Statutaires"]
df
# Out:
#      Année Perimètre juridique Perimètre spatial Spatial perimeter  \
# 2     2023              EDF SA            France            France
# 3     2023              EDF SA            France            France
# 8     2023              EDF SA            France            France
# 9     2023              EDF SA            France            France
# 10    2023              EDF SA            France            France
# 17    2023              EDF SA            France            France
# 36    2022              EDF SA            France            France
# 46    2022              EDF SA            France            France
# 59    2022              EDF SA            France            France
# 64    2022              EDF SA            France            France
# 69    2022              EDF SA            France            France
# 70    2022              EDF SA            France            France
# 82    2021              EDF SA            France            France
# ...
